# %%
#to create a caluclator window by the tkinter module
from tkinter import *
st=""
#for the caluclator window named as win
win=Tk()
win["background"]="light blue"
def press(n):
    global st
    if n=="C":
        res.delete(0,END)
    elif n=="=":
        res.delete(0, END)
        res.insert(0,eval(st))
    else:
        st=res.get()
        st=st+str(n)
        res.delete(0,END)
        res.insert(0,st)
#title name for caluclator as Anbu Caluclator
win.title("Anbu Claculator")
win.geometry("500x350")

#to create a result area or display for calculator   
res=Entry(win)
res.grid(row=1,columnspan=5)
res["font"]="helvetica 28 italic"
res["background"]="white"

#to create button 0 assigning row and column with font,backgroundcolour,fontcolour.
butn0=Button(win,text=" 0 ",command=lambda:press(0))
butn0.grid(row=2,column=0)
butn0["font"]="helvetica 25 bold"
butn0["bg"]="white"
butn0["fg"]="red"

#to create button 1 assigning row and column with font,backgroundcolour,fontcolour.
butn1=Button(win,text=" 1 ",command=lambda:press(1))
butn1.grid(row=2,column=1)
butn1["font"]="helvetica 25 bold"
butn1["bg"]="white"
butn1["fg"]="red"

#to create button 2 assigning row and column with font,backgroundcolour,fontcolour.
butn2=Button(win,text=" 2 ",command=lambda:press(2))
butn2.grid(row=2,column=3)
butn2["font"]="helvetica 25 bold"
butn2["bg"]="white"
butn2["fg"]="red"

#to create button plus assigning row and column with font,backgroundcolour,fontcolour.
butnplus=Button(win,text=" + ",command=lambda:press("+"))
butnplus.grid(row=2,column=4)
butnplus["font"]="helvetica 25 bold"
butnplus["bg"]="white"
butnplus["fg"]="blue"

#to create button 3 assigning row and column with font,backgroundcolour,fontcolour.
butn3=Button(win,text=" 3 ",command=lambda:press(3))
butn3.grid(row=3,column=0)
butn3["font"]="helvetica 25 bold"
butn3["bg"]="white"
butn3["fg"]="red"

#to create button 4 assigning row and column with font,backgroundcolour,fontcolour.
butn4=Button(win,text=" 4 ",command=lambda:press(4))
butn4.grid(row=3,column=1)
butn4["font"]="helvetica 25 bold"
butn4["bg"]="white"
butn4["fg"]="red"

#to create button 5 assigning row and column with font,backgroundcolour,fontcolour.
butn5=Button(win,text=" 5 ",command=lambda:press(5))
butn5.grid(row=3,column=3)
butn5["font"]="helvetica 25 bold"
butn5["bg"]="white"
butn5["fg"]="red"

#to create button minus assigning row and column with font,backgroundcolour,fontcolour.
butnminus=Button(win,text=" - ",command=lambda:press("-"))
butnminus.grid(row=3,column=4)
butnminus["font"]="helvetica 25 bold"
butnminus["bg"]="white"
butnminus["fg"]="blue"

#to create button 6 assigning row and column with font,backgroundcolour,fontcolour.
butn6=Button(win,text=" 6 ",command=lambda:press(6))
butn6.grid(row=4,column=0)
butn6["font"]="helvetica 25 bold"
butn6["bg"]="white"
butn6["fg"]="red"

#to create button 7 assigning row and column with font,backgroundcolour,fontcolour.
butn7=Button(win,text=" 7 ",command=lambda:press(7))
butn7.grid(row=4,column=1)
butn7["font"]="helvetica 25 bold"
butn7["bg"]="white"
butn7["fg"]="red"

#to create button 8 assigning row and column with font,backgroundcolour,fontcolour.
butn8=Button(win,text=" 8 ",command=lambda:press(8))
butn8.grid(row=4,column=3)
butn8["font"]="helvetica 25 bold"
butn8["bg"]="white"
butn8["fg"]="red"

#to create button multiply assigning row and column with font,backgroundcolour,fontcolour.
butnmul=Button(win,text=" X ",command=lambda:press("*"))
butnmul.grid(row=4,column=4)
butnmul["font"]="helvetica 25 bold"
butnmul["bg"]="white"
butnmul["fg"]="blue"

#to create button 9 assigning row and column with font,backgroundcolour,fontcolour.
butn9=Button(win,text=" 9 ",command=lambda:press(9))
butn9.grid(row=5,column=0)
butn9["font"]="helvetica 25 bold"
butn9["bg"]="white"
butn9["fg"]="red"

#to create button c assigning row and column with font,backgroundcolour,fontcolour.
butnC=Button(win,text=" C ",command=lambda:press("C"))
butnC.grid(row=5,column=1)
butnC["font"]="helvetica 25 bold"
butnC["bg"]="white"
butnC["fg"]="black"

#to create button equal assigning row and column with font,backgroundcolour,fontcolour.
butneql=Button(win,text=" = ",command=lambda:press("="))
butneql.grid(row=5,column=3)
butneql["font"]="helvetica 25 bold"
butneql["bg"]="white"
butneql["fg"]="green"

#to create button division assigning row and column with font,backgroundcolour,fontcolour.
butneql=Button(win,text=" / ",command=lambda:press("/"))
butneql.grid(row=5,column=4)
butneql["font"]="helvetica 25 bold"
butneql["bg"]="white"
butneql["fg"]="blue"

win.mainloop()
